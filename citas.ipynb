-- %% [markdown]
-- # [Estefano]

-- %%
USE [master]
GO

-- %%
/****** Object:  Database [Estefano]    Script Date: 27/08/2025 21:10:09 ******/
CREATE DATABASE [Estefano]
 CONTAINMENT = NONE
 ON  PRIMARY 
( NAME = N'Estefano', FILENAME = N'C:\Program Files\Microsoft SQL Server\MSSQL16.SQLEXPRESS\MSSQL\DATA\Estefano.mdf' , SIZE = 8192KB , MAXSIZE = UNLIMITED, FILEGROWTH = 65536KB )
 LOG ON 
( NAME = N'Estefano_log', FILENAME = N'C:\Program Files\Microsoft SQL Server\MSSQL16.SQLEXPRESS\MSSQL\DATA\Estefano_log.ldf' , SIZE = 8192KB , MAXSIZE = 2048GB , FILEGROWTH = 65536KB )
 WITH CATALOG_COLLATION = DATABASE_DEFAULT, LEDGER = OFF
GO
ALTER DATABASE [Estefano] SET COMPATIBILITY_LEVEL = 160
GO
IF (1 = FULLTEXTSERVICEPROPERTY('IsFullTextInstalled'))
begin
EXEC [Estefano].[dbo].[sp_fulltext_database] @action = 'enable'
end
GO
ALTER DATABASE [Estefano] SET ANSI_NULL_DEFAULT OFF 
GO
ALTER DATABASE [Estefano] SET ANSI_NULLS OFF 
GO
ALTER DATABASE [Estefano] SET ANSI_PADDING OFF 
GO
ALTER DATABASE [Estefano] SET ANSI_WARNINGS OFF 
GO
ALTER DATABASE [Estefano] SET ARITHABORT OFF 
GO
ALTER DATABASE [Estefano] SET AUTO_CLOSE OFF 
GO
ALTER DATABASE [Estefano] SET AUTO_SHRINK OFF 
GO
ALTER DATABASE [Estefano] SET AUTO_UPDATE_STATISTICS ON 
GO
ALTER DATABASE [Estefano] SET CURSOR_CLOSE_ON_COMMIT OFF 
GO
ALTER DATABASE [Estefano] SET CURSOR_DEFAULT  GLOBAL 
GO
ALTER DATABASE [Estefano] SET CONCAT_NULL_YIELDS_NULL OFF 
GO
ALTER DATABASE [Estefano] SET NUMERIC_ROUNDABORT OFF 
GO
ALTER DATABASE [Estefano] SET QUOTED_IDENTIFIER OFF 
GO
ALTER DATABASE [Estefano] SET RECURSIVE_TRIGGERS OFF 
GO
ALTER DATABASE [Estefano] SET  DISABLE_BROKER 
GO
ALTER DATABASE [Estefano] SET AUTO_UPDATE_STATISTICS_ASYNC OFF 
GO
ALTER DATABASE [Estefano] SET DATE_CORRELATION_OPTIMIZATION OFF 
GO
ALTER DATABASE [Estefano] SET TRUSTWORTHY OFF 
GO
ALTER DATABASE [Estefano] SET ALLOW_SNAPSHOT_ISOLATION OFF 
GO
ALTER DATABASE [Estefano] SET PARAMETERIZATION SIMPLE 
GO
ALTER DATABASE [Estefano] SET READ_COMMITTED_SNAPSHOT OFF 
GO
ALTER DATABASE [Estefano] SET HONOR_BROKER_PRIORITY OFF 
GO
ALTER DATABASE [Estefano] SET RECOVERY SIMPLE 
GO
ALTER DATABASE [Estefano] SET  MULTI_USER 
GO
ALTER DATABASE [Estefano] SET PAGE_VERIFY CHECKSUM  
GO
ALTER DATABASE [Estefano] SET DB_CHAINING OFF 
GO
ALTER DATABASE [Estefano] SET FILESTREAM( NON_TRANSACTED_ACCESS = OFF ) 
GO
ALTER DATABASE [Estefano] SET TARGET_RECOVERY_TIME = 60 SECONDS 
GO
ALTER DATABASE [Estefano] SET DELAYED_DURABILITY = DISABLED 
GO
ALTER DATABASE [Estefano] SET ACCELERATED_DATABASE_RECOVERY = OFF  
GO
ALTER DATABASE [Estefano] SET QUERY_STORE = ON
GO
ALTER DATABASE [Estefano] SET QUERY_STORE (OPERATION_MODE = READ_WRITE, CLEANUP_POLICY = (STALE_QUERY_THRESHOLD_DAYS = 30), DATA_FLUSH_INTERVAL_SECONDS = 900, INTERVAL_LENGTH_MINUTES = 60, MAX_STORAGE_SIZE_MB = 1000, QUERY_CAPTURE_MODE = AUTO, SIZE_BASED_CLEANUP_MODE = AUTO, MAX_PLANS_PER_QUERY = 200, WAIT_STATS_CAPTURE_MODE = ON)
GO

-- %% [markdown]
-- # [dbo].[citas]

-- %%
USE [Estefano]
GO

-- %%
/****** Object:  Table [dbo].[citas]    Script Date: 27/08/2025 21:10:10 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[citas](
	[id_cita] [int] IDENTITY(1,1) NOT NULL,
	[id_paciente] [int] NULL,
	[id_medico] [int] NULL,
	[fecha_cita] [datetime] NULL,
	[motivo] [text] NULL,
	[estado] [varchar](20) NULL,
	[observaciones] [text] NULL,
PRIMARY KEY CLUSTERED 
(
	[id_cita] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY] TEXTIMAGE_ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[especialidades]

-- %%
/****** Object:  Table [dbo].[especialidades]    Script Date: 27/08/2025 21:10:10 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[especialidades](
	[id_especialidad] [int] IDENTITY(1,1) NOT NULL,
	[nombre] [nvarchar](100) NOT NULL,
	[descripcion] [text] NULL,
PRIMARY KEY CLUSTERED 
(
	[id_especialidad] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY] TEXTIMAGE_ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[historialmedico]

-- %%
/****** Object:  Table [dbo].[historialmedico]    Script Date: 27/08/2025 21:10:10 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[historialmedico](
	[id_historial] [int] IDENTITY(1,1) NOT NULL,
	[id_paciente] [int] NULL,
	[id_medico] [int] NULL,
	[fecha_consulta] [datetime] NULL,
	[diagnostico] [text] NULL,
	[tratamiento] [text] NULL,
	[medicamentos] [text] NULL,
	[observaciones] [text] NULL,
PRIMARY KEY CLUSTERED 
(
	[id_historial] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY] TEXTIMAGE_ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[medicos]

-- %%
/****** Object:  Table [dbo].[medicos]    Script Date: 27/08/2025 21:10:10 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[medicos](
	[id_medico] [int] IDENTITY(1,1) NOT NULL,
	[nombre] [varchar](100) NOT NULL,
	[apellido] [varchar](100) NOT NULL,
	[cedula] [varchar](20) NOT NULL,
	[telefono] [varchar](15) NULL,
	[email] [varchar](100) NULL,
	[id_especialidad] [int] NULL,
	[fecha_contratacion] [date] NULL,
	[salario] [decimal](10, 2) NULL,
PRIMARY KEY CLUSTERED 
(
	[id_medico] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[pacientes]

-- %%
/****** Object:  Table [dbo].[pacientes]    Script Date: 27/08/2025 21:10:10 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[pacientes](
	[id_paciente] [int] IDENTITY(1,1) NOT NULL,
	[nombre] [varchar](100) NOT NULL,
	[apellidos] [varchar](100) NOT NULL,
	[cedula] [varchar](20) NOT NULL,
	[fecha_nacimiento] [date] NULL,
	[telefono] [varchar](100) NULL,
	[direccion] [text] NULL,
	[tipo_sangre] [varchar](5) NULL,
	[seguro_medico] [varchar](100) NULL,
PRIMARY KEY CLUSTERED 
(
	[id_paciente] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY] TEXTIMAGE_ON [PRIMARY]
GO

-- %% [markdown]
-- # [UQ__medicos__415B7BE5B3B491F5]

-- %%
SET ANSI_PADDING ON
GO
/****** Object:  Index [UQ__medicos__415B7BE5B3B491F5]    Script Date: 27/08/2025 21:10:10 ******/
ALTER TABLE [dbo].[medicos] ADD UNIQUE NONCLUSTERED 
(
	[cedula] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, SORT_IN_TEMPDB = OFF, IGNORE_DUP_KEY = OFF, ONLINE = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
GO

-- %% [markdown]
-- # [UQ__paciente__415B7BE5A12283AD]

-- %%
SET ANSI_PADDING ON
GO
/****** Object:  Index [UQ__paciente__415B7BE5A12283AD]    Script Date: 27/08/2025 21:10:10 ******/
ALTER TABLE [dbo].[pacientes] ADD UNIQUE NONCLUSTERED 
(
	[cedula] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, SORT_IN_TEMPDB = OFF, IGNORE_DUP_KEY = OFF, ONLINE = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
GO

-- %% [markdown]
-- # [DF__citas__estado__440B1D61]

-- %%
ALTER TABLE [dbo].[citas] ADD  DEFAULT ('programada') FOR [estado]
GO

-- %% [markdown]
-- # [FK__citas__id_medico__45F365D3]

-- %%
ALTER TABLE [dbo].[citas]  WITH CHECK ADD FOREIGN KEY([id_medico])
REFERENCES [dbo].[medicos] ([id_medico])
GO

-- %% [markdown]
-- # [FK__citas__id_pacien__44FF419A]

-- %%
ALTER TABLE [dbo].[citas]  WITH CHECK ADD FOREIGN KEY([id_paciente])
REFERENCES [dbo].[pacientes] ([id_paciente])
GO

-- %% [markdown]
-- # [FK__historial__id_me__412EB0B6]

-- %%
ALTER TABLE [dbo].[historialmedico]  WITH CHECK ADD FOREIGN KEY([id_medico])
REFERENCES [dbo].[medicos] ([id_medico])
GO

-- %% [markdown]
-- # [FK__historial__id_pa__403A8C7D]

-- %%
ALTER TABLE [dbo].[historialmedico]  WITH CHECK ADD FOREIGN KEY([id_paciente])
REFERENCES [dbo].[pacientes] ([id_paciente])
GO

-- %% [markdown]
-- # [FK__medicos__id_espe__3A81B327]

-- %%
ALTER TABLE [dbo].[medicos]  WITH CHECK ADD FOREIGN KEY([id_especialidad])
REFERENCES [dbo].[especialidades] ([id_especialidad])
GO

-- %% [markdown]
-- # [Estefano]

-- %%
USE [master]
GO

-- %%
ALTER DATABASE [Estefano] SET  READ_WRITE 
GO
